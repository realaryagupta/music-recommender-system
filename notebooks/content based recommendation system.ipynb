# %%
! pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.15.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1

# %%
# data analysis
import numpy as np
import pandas as pd

# data viz
import matplotlib.pyplot as plt
import seaborn as sns

# model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from category_encoders.count import CountEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.metrics.pairwise import cosine_similarity

# os
from pathlib import Path

# kaggle
import kagglehub

# %%
kagglehub.dataset_download("undefinenull/million-song-dataset-spotify-lastfm")
# Out:
# '/kaggle/input/million-song-dataset-spotify-lastfm'

# %%
dataset_path = Path("/kaggle/input/million-song-dataset-spotify-lastfm")

# %%
songs_path = dataset_path / 'Music Info.csv'

user_history_path = dataset_path / 'User Listening History.csv'

# %%
pd.set_option('display.max_columns', None)

# %%
df_songs_raw = pd.read_csv(songs_path)
df_songs_raw.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
# 3  rock, alternative, indie, alternative_rock, in...   NaN  2004       237026
# 4  rock, alternative, indie, alternative_rock, in...   RnB  2008       238640
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.355   0.918    1    -4.360     1       0.0746      0.001190
# 1         0.409   0.892    2    -4.373     1       0.0336      0.000807
# 2         0.508   0.826    4    -5.783     0       0.0400      0.000175
# 3         0.279   0.664    9    -8.851     1       0.0371      0.000389
# 4         0.515   0.430    7    -9.935     1       0.0369      0.010200
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000000    0.0971    0.240  148.114               4
# 1          0.000000    0.2070    0.651  174.426               4
# 2          0.000459    0.0878    0.543  120.012               4
# 3          0.000655    0.1330    0.490  104.560               4
# 4          0.000141    0.1290    0.104   91.841               4

# %%
df_users_raw = pd.read_csv(user_history_path)
df_users_raw.head()
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1

# %% [markdown]
# ### **Songs Dataset**

# %%
print(df_songs_raw.shape)
# Out:
# (50683, 21)

# %%
df_songs_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50683 entries, 0 to 50682
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_id             50683 non-null  object
#  1   name                 50683 non-null  object
#  2   artist               50683 non-null  object
#  3   spotify_preview_url  50683 non-null  object
#  4   spotify_id           50683 non-null  object
#  5   tags                 49556 non-null  object
#  6   genre                22348 non-null  object
#  7   year                 50683 non-null  int64
#  8   duration_ms          50683 non-null  int64
#  9   danceability         50683 non-null  float64
#  10  energy               50683 non-null  float64
#  11  key                  50683 non-null  int64
#  12  loudness             50683 non-null  float64
#  13  mode                 50683 non-null  int64
#  14  speechiness          50683 non-null  float64
#  15  acousticness         50683 non-null  float64
#  16  instrumentalness     50683 non-null  float64
#  17  liveness             50683 non-null  float64
#  18  valence              50683 non-null  float64
#  19  tempo                50683 non-null  float64
#  20  time_signature       50683 non-null  int64
# dtypes: float64(9), int64(5), object(7)
# memory usage: 8.1+ MB

# %%
df_songs_raw.isna().sum().sort_values(ascending = False).head(3)
# Out:
# genre     28335
# tags       1127
# artist        0
# dtype: int64

# %% [markdown]
# There are 55% **Missing Values** in `genre` and 2% Missing values in `tags`.

# %%
missing_percent = (df_songs_raw.isnull().sum() / df_songs_raw.shape[0]) * 100

# %%
missing_percent.sort_values(ascending = False).head(3)
# Out:
# genre     55.906320
# tags       2.223625
# artist     0.000000
# dtype: float64

# %%
df_songs_raw.drop_duplicates(subset=["spotify_id", "year", "duration_ms"], inplace = True)
df_songs_raw.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
# 3  rock, alternative, indie, alternative_rock, in...   NaN  2004       237026
# 4  rock, alternative, indie, alternative_rock, in...   RnB  2008       238640
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.355   0.918    1    -4.360     1       0.0746      0.001190
# 1         0.409   0.892    2    -4.373     1       0.0336      0.000807
# 2         0.508   0.826    4    -5.783     0       0.0400      0.000175
# 3         0.279   0.664    9    -8.851     1       0.0371      0.000389
# 4         0.515   0.430    7    -9.935     1       0.0369      0.010200
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000000    0.0971    0.240  148.114               4
# 1          0.000000    0.2070    0.651  174.426               4
# 2          0.000459    0.0878    0.543  120.012               4
# 3          0.000655    0.1330    0.490  104.560               4
# 4          0.000141    0.1290    0.104   91.841               4

# %%
# removing columns not required for collaborative filtering

cols_to_drop = ["track_id", "name", "spotify_preview_url", "spotify_id", "genre"]
df_features = df_songs_raw.drop(columns=cols_to_drop).copy()

# %%
df_features.head()
# Out:
#             artist                                               tags  year  \
# 0      The Killers  rock, alternative, indie, alternative_rock, in...  2004
# 1            Oasis  rock, alternative, indie, pop, alternative_roc...  2006
# 2          Nirvana   rock, alternative, alternative_rock, 90s, grunge  1991
# 3  Franz Ferdinand  rock, alternative, indie, alternative_rock, in...  2004
# 4        Radiohead  rock, alternative, indie, alternative_rock, in...  2008
#
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       222200         0.355   0.918    1    -4.360     1       0.0746
# 1       258613         0.409   0.892    2    -4.373     1       0.0336
# 2       218920         0.508   0.826    4    -5.783     0       0.0400
# 3       237026         0.279   0.664    9    -8.851     1       0.0371
# 4       238640         0.515   0.430    7    -9.935     1       0.0369
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0      0.001190          0.000000    0.0971    0.240  148.114               4
# 1      0.000807          0.000000    0.2070    0.651  174.426               4
# 2      0.000175          0.000459    0.0878    0.543  120.012               4
# 3      0.000389          0.000655    0.1330    0.490  104.560               4
# 4      0.010200          0.000141    0.1290    0.104   91.841               4

# %%
# check for missing values
df_features.isna().sum().sort_values(ascending = False).head(2)
# Out:
# tags      1126
# artist       0
# dtype: int64

# %%
df_features.fillna({"tags": "no_tags"}, inplace=True)
df_features["artist"] = df_features["artist"].str.lower()

# %%
# fill the tags column missing values with string "no_tags"
df_features.fillna({"tags": "no_tags"}, inplace=True)

# %%
# check for missing values
df_features["artist"] = df_features["artist"].str.lower()

# %%
tag_counts = (
    df_songs_raw["tags"].str.lower()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
)

popular_tags = tag_counts[tag_counts >= 1000]

# %%
popular_tags = tag_counts[tag_counts >= 1000]

# %%
popular_tags.head(5)
# Out:
# tags
# rock           10681
# indie           7284
# electronic      6592
# alternative     6271
# pop             4650
# Name: count, dtype: int64

# %%
freq_enc_cols = ['year']
one_hot_cols = ['artist', 'time_signature', 'key']
tfidf_text_col = 'tags'
std_scale_cols = ["duration_ms", "loudness", "tempo"]
minmax_scale_cols = ["danceability", "energy", "speechiness", "acousticness",
                     "instrumentalness", "liveness", "valence"]

total_trans_cols = len(freq_enc_cols + one_hot_cols + std_scale_cols + minmax_scale_cols)
print("Total features for transformation:", total_trans_cols)
# Out:
# Total features for transformation: 14

# %%
preprocessor = ColumnTransformer(transformers = [
    ("freq_enc", CountEncoder(normalize = True, return_df = True), freq_enc_cols),
    ("ohe", OneHotEncoder(handle_unknown = "ignore"), one_hot_cols),
    ("tfidf", TfidfVectorizer(max_features = 85), tfidf_text_col),
    ("std_scaler", StandardScaler(), std_scale_cols),
    ("minmax_scaler", MinMaxScaler(), minmax_scale_cols)
], remainder = 'passthrough', n_jobs = -1, verbose_feature_names_out = False)

# %%
preprocessor
# Out:
# ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                   transformers=[('freq_enc',
#                                  CountEncoder(combine_min_nan_groups=True,
#                                               normalize=True),
#                                  ['year']),
#                                 ('ohe', OneHotEncoder(handle_unknown='ignore'),
#                                  ['artist', 'time_signature', 'key']),
#                                 ('tfidf', TfidfVectorizer(max_features=85),
#                                  'tags'),
#                                 ('std_scaler', StandardScaler(),
#                                  ['duration_ms', 'loudness', 'tempo']),
#                                 ('minmax_scaler', MinMaxScaler(),
#                                  ['danceability', 'energy', 'speechiness',
#                                   'acousticness', 'instrumentalness',
#                                   'liveness', 'valence'])],
#                   verbose_feature_names_out=False)

# %%
preprocessor.fit(df_features)
df_transformed = preprocessor.transform(df_features)

# %%
print(df_transformed.shape)
df_transformed[:3]
# Out:
# (50674, 8431)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 62 stored elements and shape (3, 8431)>

# %%
df_songs_raw[df_songs_raw["artist"] == "Coldplay"].head()
# Out:
#               track_id           name    artist  \
# 6   TRVCCWR128F9304A30   Viva la Vida  Coldplay
# 8   TRMZXEW128F9341FD5  The Scientist  Coldplay
# 9   TRUJIIV12903CA8848         Clocks  Coldplay
# 14  TRXNTMB12903CA884A        Fix You  Coldplay
# 56  TRCYFSS128F934406C    Don't Panic  Coldplay
#
#                                   spotify_preview_url              spotify_id  \
# 6   https://p.scdn.co/mp3-preview/ab747fed1bfab2ac...  08A1lZeyLMWH58DT6aYjnC
# 8   https://p.scdn.co/mp3-preview/95cb9df1b056d759...  0GSSsT9szp0rJkBrYkzy6s
# 9   https://p.scdn.co/mp3-preview/24c7fe858b234e3c...  0BCPKOYdS2jbQ8iyB56Zns
# 14  https://p.scdn.co/mp3-preview/b1640815319b2df5...  0Kk4dfh9Kq7Okg4T58IBVR
# 56  https://p.scdn.co/mp3-preview/18d587e6cdcd4e7f...  0MbCcvzLYu3xq6OgEkSbhC
#
#                                                  tags genre  year  \
# 6   rock, alternative, indie, pop, alternative_roc...   NaN  2013
# 8   rock, alternative, indie, pop, alternative_roc...  Rock  2007
# 9   rock, alternative, indie, pop, alternative_roc...   NaN  2002
# 14  rock, alternative, indie, pop, alternative_roc...   NaN  2016
# 56  rock, alternative, indie, pop, alternative_roc...   NaN  1999
#
#     duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 6        235384         0.588   0.806    8    -7.903     1       0.1050
# 8        311014         0.566   0.429    5    -7.826     1       0.0242
# 9        307879         0.577   0.749    5    -7.215     0       0.0279
# 14       295826         0.213   0.416    3    -8.683     1       0.0336
# 56       158426         0.620   0.600    0   -10.061     1       0.0493
#
#     acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 6         0.1530          0.000000    0.0634    0.520  137.973               4
# 8         0.7150          0.000014    0.1200    0.173  146.365               4
# 9         0.5990          0.011500    0.1830    0.255  130.970               4
# 14        0.1640          0.001680    0.1100    0.129  138.478               4
# 56        0.0345          0.514000    0.1080    0.427  118.016               4

# %%
song_input_row = df_features[df_songs_raw["name"] == "The Gauntlet"]

if not song_input_row.empty:
    input_vector = preprocessor.transform(song_input_row)

# %%
similarities = cosine_similarity(df_transformed, input_vector)
similarities.shape
# Out:
# (50674, 1)

# %%
top_indices = np.argsort(similarities.ravel())[-11:][::-1]
df_songs_raw.iloc[top_indices].head(5)
# Out:
#                  track_id               name            artist  \
# 13983  TRMIEPT128F4297BD7       The Gauntlet  Dropkick Murphys
# 20210  TRXYOJK12903CAC768     A Few Good Men  Dropkick Murphys
# 13928  TRXINZE128F92EC8C4        Never Alone  Dropkick Murphys
# 40675  TRUXYQN128F934DC64           Rooftops     Alkaline Trio
# 13965  TRKKFES128F92EEFF3  Black Velvet Band  Dropkick Murphys
#
#                                      spotify_preview_url  \
# 13983  https://p.scdn.co/mp3-preview/6d27508da8653929...
# 20210  https://p.scdn.co/mp3-preview/5760af29403ad796...
# 13928  https://p.scdn.co/mp3-preview/2518cacd3705e458...
# 40675  https://p.scdn.co/mp3-preview/6f1abcb8d0c3bf31...
# 13965  https://p.scdn.co/mp3-preview/90eb4e82658eb136...
#
#                    spotify_id                       tags genre  year  \
# 13983  1RkIYoHyYKR8ZlbFM3FZPx            punk, punk_rock   NaN  2001
# 20210  0u3jw4N4HKJrr0mcyrNkO5  punk, hardcore, punk_rock   NaN  2001
# 13928  1gVQoSBuTgAYiXk427UiYE            punk, punk_rock   NaN  1998
# 40675  0Ul4Q6fUufEYxTUuG4Ovca     punk, punk_rock, cover   NaN  2007
# 13965  2LXjAuHyvlQl426hSjCMnD     punk, punk_rock, cover   NaN  2003
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 13983       167866         0.200   0.965    2    -4.690     1       0.1200
# 20210       156480         0.301   0.927    2    -4.659     1       0.0516
# 13928       174171         0.239   0.948    9    -3.466     1       0.0705
# 40675       135253         0.303   0.906    2    -5.408     1       0.0562
# 13965       183306         0.237   0.945    7    -2.825     1       0.0761
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 13983      0.000398          0.000008    0.0638    0.642  172.151
# 20210      0.003690          0.000000    0.5790    0.703  147.802
# 13928      0.000067          0.000000    0.1500    0.868  168.425
# 40675      0.005160          0.000002    0.1140    0.592  156.047
# 13965      0.024200          0.000000    0.2710    0.567  157.387
#
#        time_signature
# 13983               4
# 20210               4
# 13928               4
# 40675               4
# 13965               4

# %%
def recommend(song_name, song_data, feature_matrix, top_k=10):
    match = song_data[song_data["name"] == song_name]
    if match.empty:
        print("Song not found.")
        return
    song_idx = match.index[0]
    input_vec = feature_matrix[song_idx].reshape(1, -1)
    similarity = cosine_similarity(input_vec, feature_matrix)
    top_indices = np.argsort(similarity.ravel())[-(top_k+1):][::-1]
    top_recommendations = song_data.iloc[top_indices][['name', 'artist', 'spotify_preview_url']].reset_index(drop = True)
    return top_recommendations

# %%
recommend("The Gauntlet", song_data=df_songs_raw, feature_matrix = df_transformed, top_k = 10)
# Out:
#                     name             artist  \
# 0          Sell Yourself  Cage the Elephant
# 1   Drones In The Valley  Cage the Elephant
# 2               Cash Cow  We Are Scientists
# 3       The Holiday Song             Pixies
# 4              Free Love  Cage the Elephant
# 5      Sticks And Stones     Alien Ant Farm
# 6     Here It Goes Again              OK Go
# 7        Fear Of Falling        Maxïmo Park
# 8           Pennsylvania    Bloodhound Gang
# 9               Minority          Green Day
# 10              Pictures   System of a Down
#
#                                   spotify_preview_url
# 0   https://p.scdn.co/mp3-preview/f4cc484e715a22ae...
# 1   https://p.scdn.co/mp3-preview/1c3129b069e2ff6b...
# 2   https://p.scdn.co/mp3-preview/c0d35dc1927a5d06...
# 3   https://p.scdn.co/mp3-preview/e70b6a03080d9e7f...
# 4   https://p.scdn.co/mp3-preview/c23d2c9f53322561...
# 5   https://p.scdn.co/mp3-preview/2d17ce3c54d25aca...
# 6   https://p.scdn.co/mp3-preview/7327e3ac55e46020...
# 7   https://p.scdn.co/mp3-preview/5df5e8d762b9a43a...
# 8   https://p.scdn.co/mp3-preview/39030ccfebe6811c...
# 9   https://p.scdn.co/mp3-preview/eda685fb47cabb7b...
# 10  https://p.scdn.co/mp3-preview/8d88be06f4e4c809...
